# %% [markdown]
# # Show the predicted results for a single patient

# %%
import os
from scipy import misc

# %%
# %pylab inline --no-import-all
from PIL import Image
# Out:
# /Users/peterhirt/anaconda/envs/theano/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
from ipywidgets import widgets  
from ipywidgets import interact

# %%
current=os.getcwd()
(top,tail) = os.path.split(current)
path_to = 'predict'
predict_dir = os.path.join(top,path_to)
print (os.listdir(predict_dir))
# Out:
# ['.DS_Store', '107', '121', '138', 'predicterrorfile.txt']

# %%
from IPython.display import Image, display

# %%
# choose patient 

patient_ID = 138

# %%
cwd=os.getcwd()
(cwdtop,tail) = os.path.split(cwd)

path_name = 'predict/' + str(patient_ID) + '/' + 'predicted_results'

jpg_dir = os.path.join(cwdtop,path_name)

print jpg_dir

jpg_list = (os.listdir(jpg_dir))


j = 0

for jpg_image in jpg_list:
    jpg_list[j] = '../' + path_name + '/' + jpg_list[j] 
    
    #print jpg_list[i]
    
    j = j + 1
# Out:
# /Users/peterhirt/datascience/ild-cnn/predict/138/predicted_results

# %%
def browse_images(images):
    n = len(images)
    print n
    
    
    def view_image(i):
        display(Image(filename=images[i]))
    interact(view_image, i=(0,n-1))

# %%
browse_images(jpg_list)
