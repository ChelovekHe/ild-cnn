# %% [markdown]
# # Show the predicted results for a single patient

# %%
import os
from scipy import misc

# %%
# %pylab inline --no-import-all
from PIL import Image
# Out:
# /Users/peterhirt/anaconda/envs/theano/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
from ipywidgets import widgets  
from ipywidgets import interact

# %%
# choose patient 

patient_ID = 121

# %%
# not used

'''
text = widgets.Text()
display(text)

def handle_submit(sender):
    print(text.value)
    patient_ID = text.value
    

text.on_submit(handle_submit)
'''
# Out:
# '\ntext = widgets.Text()\ndisplay(text)\n\ndef handle_submit(sender):\n    print(text.value)\n    patient_ID = text.value\n    \n\ntext.on_submit(handle_submit)\n'

# %%
cwd=os.getcwd()
(cwdtop,tail) = os.path.split(cwd)

path_name = 'predict/' + str(patient_ID) + '/' + 'patch_jpeg'

jpg_dir = os.path.join(cwdtop,path_name)

print jpg_dir

patient_list = (os.listdir(jpg_dir))

type(patient_list)

i = 0

for patient in patient_list:
    patient_list[i] = '../predict/121/patch_jpeg/' + patient_list[i] 
    i = i + 1
# Out:
# /Users/peterhirt/datascience/ild-cnn/predict/121/patch_jpeg

# %%
def browse_images(images):
    n = len(images)
    def view_image(i):
        display(Image(filename=images[i]))
    interact(view_image, i=(0,n-1))

# %%
browse_images(patient_list)
